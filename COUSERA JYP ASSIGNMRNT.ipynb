# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **SOLOMON KOBBY EWUDZIE
#
# Data Scientist

# %% [markdown]
# _I am interested in Data Science Because it allows analysis and is a niche space for creativity as well as critical thinking. Its for genuises!

# %% [markdown]
# ### display the name of the Author

# %%
print ("the author is King Kobby")
# Out:
# the author is King Kobby

# %% [markdown]
# https://jupyter.org/
#
# ![] https://res.cloudinary.com/edlitera/image/upload/c_fill,f_auto,w_400/v1594223868/blog/udhxelgnyko7vezivybe
#
# ![photo.jpg](attachment:photo.jpg)
#
# 1. Jax
# 2. Shclutz
# 3. Van
